# %%
import os
import sys
import time
import traceback as tb
from typing import List, Tuple, Dict, Set, Union, Callable, Optional

import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.models
from torchvision import transforms

# %%
class Block(nn.Module):
    def __init__(
        self, 
        in_channels: int, 
        out_channels: int, 
        stride: int = 1,
        identity_downsample = None
    ):
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.stride = stride
        self.identity_downsample = identity_downsample

        self.model = nn.Sequential(
            # (1.)
            nn.BatchNorm2d(
                num_features=self.in_channels, 
                track_running_stats=False
            ),
            nn.ReLU(inplace=True),
            nn.Conv2d(
                in_channels=self.in_channels, 
                out_channels=self.out_channels, 
                kernel_size=1,
                stride=self.stride, #1,
                padding=0,
                bias=False
            ),
            # (2.)
            nn.BatchNorm2d(
                num_features=self.out_channels,
                track_running_stats=False
            ),
            nn.ReLU(inplace=True),
            nn.Conv2d(
                in_channels=self.out_channels, 
                out_channels=self.out_channels, 
                kernel_size=3,
                stride=1, #self.stride,
                padding=1,
                bias=False
            ),
            # (3.)
            nn.BatchNorm2d(
                num_features=self.out_channels,
                track_running_stats=False
            ),
            nn.ReLU(inplace=True),
            nn.Conv2d(
                in_channels=self.out_channels, 
                out_channels=self.out_channels*4, 
                kernel_size=1,
                stride=1,
                padding=0,
                bias=False
            )   
        )

    def forward(self, input):
        output = self.model(input)
        if self.identity_downsample:
            input = self.identity_downsample(input)
        output += input
        return output

block = Block(64, 64, 2, None)
print(block.model)
# Out:
# Sequential(
#   (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#   (1): ReLU(inplace=True)
#   (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#   (4): ReLU(inplace=True)
#   (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#   (7): ReLU(inplace=True)
#   (8): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# )

# %%
class Resnet(nn.Module):
    def __init__(
        self,
        num_channels: int = 1, 
        num_out_features: int = 10,
        num_blocks_per_layer: List[int] = [3, 8, 36, 3]
    ):
        super().__init__()
        
        self.in_channels = 64
        self.num_channels = num_channels
        self.num_out_features = num_out_features
        self.num_blocks_per_layer = num_blocks_per_layer

        self.model = nn.Sequential(
            nn.Conv2d(
                in_channels=self.num_channels,
                out_channels=64,
                kernel_size=7,
                stride=2,
                padding=3,
                bias=False  
            ),
            nn.BatchNorm2d(
                num_features=64,
                track_running_stats=False
            ),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(
                kernel_size=3,
                stride=2,
                padding=1
            ),
            self.get_block_layer(
                num_blocks=self.num_blocks_per_layer[0],
                out_channels=64,
                stride=1
            ),
            self.get_block_layer(
                num_blocks=self.num_blocks_per_layer[1],
                out_channels=128,
                stride=2
            ),
            self.get_block_layer(
                num_blocks=self.num_blocks_per_layer[2],
                out_channels=256,
                stride=2
            ),
            self.get_block_layer(
                num_blocks=self.num_blocks_per_layer[3],
                out_channels=512,
                stride=2
            ),
            nn.AdaptiveAvgPool2d(output_size=(1, 1)),
            nn.Flatten(),
            nn.Linear(
                in_features=512*4,
                out_features=self.num_out_features,
                bias=True
            )
        )

    def get_block_layer(self, num_blocks: int, out_channels: int, stride: int):

        identity_downsample = None
        if (stride != 1) or (self.in_channels != 4 * out_channels):
            identity_downsample = nn.Sequential(
                nn.Conv2d(
                    in_channels=self.in_channels, 
                    out_channels=out_channels * 4,
                    kernel_size=1,
                    stride=stride,
                ),
                nn.BatchNorm2d(num_features=out_channels * 4)
            )

        layers = nn.Sequential(
            Block(
                in_channels=self.in_channels, 
                out_channels=out_channels, 
                stride=stride,
                identity_downsample=identity_downsample
            )
        )

        self.in_channels = out_channels * 4

        for _ in range(1, num_blocks):
            layers.append(
                Block(
                    in_channels=self.in_channels,
                    out_channels=out_channels,
                    stride=1,
                    identity_downsample=None
                )
            )

        return layers

    def forward(self, input):
        output = self.model(input)
        return output

resnet = Resnet(num_channels=1, num_out_features=10)
print(resnet.model)
# Out:
# Sequential(
#   (0): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): Block(
#       (identity_downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (model): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (1): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (2): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#   )
#   (5): Sequential(
#     (0): Block(
#       (identity_downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (model): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (1): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (2): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (3): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (4): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (5): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (6): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (7): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#   )
#   (6): Sequential(
#     (0): Block(
#       (identity_downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (model): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (1): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (2): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (3): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (4): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (5): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (6): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (7): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (8): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (9): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (10): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (11): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (12): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (13): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (14): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (15): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (16): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (17): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (18): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (19): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (20): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (21): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (22): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (23): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (24): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (25): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (26): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (27): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (28): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (29): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (30): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (31): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (32): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (33): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (34): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (35): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#   )
#   (7): Sequential(
#     (0): Block(
#       (identity_downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (model): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (1): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (2): Block(
#       (model): Sequential(
#         (0): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (4): ReLU(inplace=True)
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (7): ReLU(inplace=True)
#         (8): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=(1, 1))
#   (9): Flatten(start_dim=1, end_dim=-1)
#   (10): Linear(in_features=2048, out_features=10, bias=True)
# )

# %%
x = torch.rand(64, 1, 28, 28)
out = resnet(x)
print(out.shape)
# Out:
# torch.Size([64, 10])
